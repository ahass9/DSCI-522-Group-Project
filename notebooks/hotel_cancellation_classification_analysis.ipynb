# %% [markdown]
# # Binary Classification of Hotel Cancellations

# %% [markdown]
# ## Summary

# %% [markdown]
# In this project we worked with an open hotel booking dataset containing reservations for both city and resort hotels and we selected a smaller set of features that would realistically be available at the time of booking, such as lead time, whether the guest is a repeat customer, previous cancellations, booking changes, special requests, reserved room type and deposit type. After a brief exploratory analysis, we confirmed that cancellations are fairly common and that patterns differ across hotel types and booking conditions, especially for repeated guests and deposit policies. We then framed the problem as a binary classification task: predict whether a booking will be cancelled or not. The data was split into training and test sets, and we built pipelines that combined preprocessing with three models: K-Nearest Neighbours, a decision tree and an RBF-kernel SVM.
#
# Using 5-fold cross validation with F1 score on the validation set, KNN gave the best performance, so we chose it as our final model and evaluated it on the unseen test data. On the test set, our KNN model performs well enough with an accuracy of 73% and that it could plausibly support day-to-day hotel operations, at least as a first-pass tool for flagging higher-risk bookings. The confusion matrix shows that the model correctly identifies most non-cancellations and captures a reasonable portion of true cancellations, even though it still misses some risky bookings. That said, we do not see it as a finished solution. There is clear value in extending the feature set, tuning the model more carefully, and examining in detail which types of reservations are consistently misclassified. This would not only improve raw performance, but also give hotels a better sense of when to rely on the model’s predictions and when they should be treated as one input alongside staff experience and existing booking policies.

# %% [markdown]
# ## Introduction

# %% [markdown]
# Free cancellations for hotel bookings are increasingly popular nowadays, but cancellations create significant impact on a hotel's revenue and operation. Predicting whether a reservation will be canceled can help hotels manage resources more effectively, reduce lost revenue, and improve customer service. There has been a rise in the research conducted on predicting hotel cancellations using machine learning models in order to improve strategies for revenue management (Sánchez, 2020, Antonio, 2017).
#
#
# In our project, we aim to answer the question "can we build a model that accurately predicts whether a hotel booking will be canceled?" This will be a binary classification problem, where each booking is labeled as either “canceled” or “not canceled”.
#
#
# To explore this, we used a publicly available dataset from [GitHub](https://raw.githubusercontent.com/manthangandhi/hotel_cancellation_prediction/refs/heads/main/data/hotel_bookings.csv). The dataset contains information about hotel reservations, and the label column is called "IsCanceled", which indicates whether a booking was canceled or not. One of the important features is "Lead Time", showing how many days passed between the booking date and the arrival date. Some other important features include deposit type, is_repeated_guest and booking_changes, which are all helpful for our classification model and have been used in previous work done that has also conducted predictive modeling on hotel cancelations (Antonio, 2019).

# %% [markdown]
# ## Question of Interest:
# Since the dataset contains a lot of features (32 in total), we chose to examine a subset of these in order to focus our research question to the following:
#
# **Can we predict hotel cancellations from booking lead time and different types of guest behaviors, using hotel booking information from the year 2017? And do cancellations differ across hotel type?**

# %% [markdown]
# ## Methods: Data Summary + EDA + Validation

# %% [markdown]
# We began by cleaning the dataset and selecting the columns that are useful for our research question. Our analysis depends on the following columns as predictors: hotel, is_canceled, lead_time, previous_cancellations,previous_bookings_not_canceled, booking_changes,total_of_special_requests, is_repeated_guest, deposit_type and reserved_room_type.
#
# To ensure quality and integrity of the data prior to modelling, we used the pandera package to conduct a series of validation checks. These checks enforced correct column name and column types, valid category levels and numerical bounds for our predictor variables. We then performed exploratory data analysis (EDA) to examine the distribution of our predictor variables across different levels of our target variable, 'is_canceled'.
#
# For predictive modeling, we conducted cross validation on 3 different models: KNN, SVM RBF and Decision trees, using our training data. The best performing model (KNN) was then evaluated on the test set to assess whether it generalizes well to unseen data and evaluate how well it was able to correctly predict guests that cancel their hotel reservations versus those who do not.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import altair as alt
alt.data_transformers.enable("default")
alt.data_transformers.disable_max_rows()
alt.renderers.enable('png')
# Out:
# RendererRegistry.enable('png')

# %%
data = pd.read_csv('https://raw.githubusercontent.com/manthangandhi/hotel_cancellation_prediction/refs/heads/main/data/hotel_bookings.csv')

# %%
cols_of_interest = [
    "hotel",
    "arrival_date_year",
    "is_canceled", 
    "lead_time",
    "previous_cancellations",
    "previous_bookings_not_canceled",
    "booking_changes",
    "total_of_special_requests",
    "is_repeated_guest",
    "deposit_type",
    "reserved_room_type"
]

hotel_data = data[cols_of_interest]

# %%
hotel_data['arrival_date_year'].value_counts()
# Out:
# arrival_date_year
# 2016    56707
# 2017    40687
# 2015    21996
# Name: count, dtype: int64

# %% [markdown]
# Since the entire dataset is quite large, we'll be focusing on hotel data from the most recent year, the year 2017, to make predictions about hotel cancellations (as per the research question).

# %%
data_2017 = hotel_data[hotel_data['arrival_date_year'] == 2017]

# %%
data_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40687 entries, 9775 to 119389
# Data columns (total 11 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           40687 non-null  object
#  1   arrival_date_year               40687 non-null  int64
#  2   is_canceled                     40687 non-null  int64
#  3   lead_time                       40687 non-null  int64
#  4   previous_cancellations          40687 non-null  int64
#  5   previous_bookings_not_canceled  40687 non-null  int64
#  6   booking_changes                 40687 non-null  int64
#  7   total_of_special_requests       40687 non-null  int64
#  8   is_repeated_guest               40687 non-null  int64
#  9   deposit_type                    40687 non-null  object
#  10  reserved_room_type              40687 non-null  object
# dtypes: int64(8), object(3)
# memory usage: 3.7+ MB

# %% [markdown]
# We can see from the output above that there are no missing values present after choosing the columns of interest that match our focused research question.

# %%
#now that we don't need the year column, we can drop it
hotel_data_cleaned = data_2017.drop(columns=['arrival_date_year'])
hotel_data_cleaned
# Out:
#                hotel  is_canceled  lead_time  previous_cancellations  \
# 9775    Resort Hotel            1         74                       0
# 9776    Resort Hotel            1         62                       0
# 9777    Resort Hotel            1         62                       0
# 9778    Resort Hotel            1         62                       0
# 9779    Resort Hotel            1         71                       0
# ...              ...          ...        ...                     ...
# 119385    City Hotel            0         23                       0
# 119386    City Hotel            0        102                       0
# 119387    City Hotel            0         34                       0
# 119388    City Hotel            0        109                       0
# 119389    City Hotel            0        205                       0
#
#         previous_bookings_not_canceled  booking_changes  \
# 9775                                 0                0
# ...

# %% [markdown]
# ### Addressing Duplicates:
#
# Since our dataset does not contain an ID column which can be used to filter out duplicate observations, and since a lot of hotel reservations can look identical across all features, we have chosen not to drop duplicates blindy. Instead, we consulted the literature that confirms that 'Each observation represents a hotel booking' (Antonio, 2019).

# %% [markdown]
# ## Data Validation

# %%
import pandera as pa
import pandera.pandas as pa
from pandera import Check

# 1) Check for Correct data file format
url = "https://raw.githubusercontent.com/manthangandhi/hotel_cancellation_prediction/refs/heads/main/data/hotel_bookings.csv"
assert url.lower().endswith(".csv"), f"Expected a .csv URL, got: {url}"
print("✅ File format check passed (.csv).")

EXPECTED_COLS = [
    "hotel",
    "is_canceled",
    "lead_time",
    "previous_cancellations",
    "previous_bookings_not_canceled",
    "booking_changes",
    "total_of_special_requests",
    "is_repeated_guest",
    "deposit_type",
    "reserved_room_type",
]

MISSINGNESS_THRESHOLD = 0.0  # since there are no missing values as we saw earlier, we expect 0 missingness

def col_with_missingness(dtype, col_name):
    return pa.Column(dtype,
        nullable=True,  # we added nullable=True, but enforced threshold below
        checks=Check(
            lambda s: s.isna().mean() <= MISSINGNESS_THRESHOLD,
            element_wise=False,
            # 4) Check for Missingness not beyond expected threshold
            error=f"Too many missing values in '{col_name}' (>{MISSINGNESS_THRESHOLD:.0%}).",
        ),
    )

hotel_cleaned_schema = pa.DataFrameSchema(
    {   # 2) Check for correct column names, comparing the columns array with df columns
        "hotel": col_with_missingness(str, "hotel"),
        "is_canceled": col_with_missingness(int, "is_canceled"),
        "lead_time": col_with_missingness(int, "lead_time"),
        "previous_cancellations": col_with_missingness(int, "previous_cancellations"),
        "previous_bookings_not_canceled": col_with_missingness(int, "previous_bookings_not_canceled"),
        "booking_changes": col_with_missingness(int, "booking_changes"),
        "total_of_special_requests": col_with_missingness(int, "total_of_special_requests"),
        "is_repeated_guest": col_with_missingness(int, "is_repeated_guest"),
        "deposit_type": col_with_missingness(str, "deposit_type"),
        "reserved_room_type": col_with_missingness(str, "reserved_room_type"),
    }, checks=[
        # 3) Check for No empty observations (no row where all values are NA)
        Check(lambda df: ~(df.isna().all(axis=1)).any(), error="Empty rows found."),
    ],strict=True,
)

# Running validation
try:
    hotel_data_validated = hotel_cleaned_schema.validate(hotel_data_cleaned, lazy=True)
    print("✅ Pandera validation passed: column names, no empty rows, missingness threshold.")
except pa.errors.SchemaErrors as e:
    print("❌ Pandera validation failed. Showing first few failure cases:")
    print(e.failure_cases.head(10))
    raise
# Out:
# ✅ File format check passed (.csv).
# ✅ Pandera validation passed: column names, no empty rows, missingness threshold.

# %%
from pandera import Column, Check

# Setting up categories and numeric data 
hotel_categories = hotel_data_cleaned["hotel"].unique().tolist()
deposit_categories = hotel_data_cleaned["deposit_type"].unique().tolist()
room_categories = hotel_data_cleaned["reserved_room_type"].unique().tolist()


lead_time_min = int(hotel_data_cleaned["lead_time"].min())
lead_time_max = int(hotel_data_cleaned["lead_time"].max())

prev_canc_min = int(hotel_data_cleaned["previous_cancellations"].min())
prev_canc_max = int(hotel_data_cleaned["previous_cancellations"].max())

prev_not_canc_min = int(hotel_data_cleaned["previous_bookings_not_canceled"].min())
prev_not_canc_max = int(hotel_data_cleaned["previous_bookings_not_canceled"].max())

booking_changes_min = int(hotel_data_cleaned["booking_changes"].min())
booking_changes_max = int(hotel_data_cleaned["booking_changes"].max())

special_req_min = int(hotel_data_cleaned["total_of_special_requests"].min())
special_req_max = int(hotel_data_cleaned["total_of_special_requests"].max())

schema_dtypes = pa.DataFrameSchema(
    {
        "hotel": Column(str),
        "is_canceled": Column(int),
        "lead_time": Column(int),
        "previous_cancellations": Column(int),
        "previous_bookings_not_canceled": Column(int),
        "booking_changes": Column(int),
        "total_of_special_requests": Column(int),
        "is_repeated_guest": Column(int),
        "deposit_type": Column(str),
        "reserved_room_type": Column(str),
    }    
)

try:
    validated_dtypes = schema_dtypes.validate(hotel_data_cleaned, lazy=True)
    print("✅ Pandera validation passed: Data types are correct.")
except pa.errors.SchemaErrors as e:
    print("❌ Pandera validation failed. Showing first few failure cases:")
    print(e.failure_cases.head(10))
    raise

schema_categories = pa.DataFrameSchema(
    {
        "hotel": Column(str, Check.isin(hotel_categories)),
        "deposit_type": Column(str, Check.isin(deposit_categories)),
        "reserved_room_type": Column(str, Check.isin(room_categories)),
        "is_canceled": Column(int, Check.isin([0, 1])),
        "is_repeated_guest": Column(int, Check.isin([0, 1])),
    }
)

try:
    validated_categories = schema_categories.validate(hotel_data_cleaned, lazy=True)
    print("✅ Pandera validation passed: Correct category levels.")
except pa.errors.SchemaErrors as e:
    print("❌ Pandera validation failed. Showing first few failure cases:")
    print(e.failure_cases.head(10))
    raise

schema_outliers = pa.DataFrameSchema(
    {
        "lead_time": Column(int, Check.ge(0)),
        "previous_cancellations": Column(int, Check.ge(0)),
        "previous_bookings_not_canceled": Column(int, Check.ge(0)),
        "booking_changes": Column(int, Check.ge(0)),
        "total_of_special_requests": Column(int, Check.ge(0)),
    }
)
validated_outliers = schema_outliers.validate(hotel_data_cleaned, lazy=True)

try:
    validated_dtypes = schema_dtypes.validate(hotel_data_cleaned, lazy=True)
    print("✅ Pandera validation passed: No outliers.")
except pa.errors.SchemaErrors as e:
    print("❌ Pandera validation failed. Showing first few failure cases:")
    print(e.failure_cases.head(10))
    raise
# Out:
# ✅ Pandera validation passed: Data types are correct.
# ✅ Pandera validation passed: Correct category levels.
# ✅ Pandera validation passed: No outliers.

# %%
import numpy as np

# Load data
# df = data
df = hotel_data_cleaned

# Target variable
TARGET = "is_canceled"

# Bounds for target class proportions (has to be binary 0 or 1)
TARGET_PROP_BOUNDS = (0.2, 0.8)


# Features to exclude
EXCLUDE = set()

FEATURES = [col for col in df.columns if col != TARGET and col not in EXCLUDE]


# Helper functions
def proportion_bounds(series, lower, upper):
    """
    Validate that binary class proportions fall within [lower, upper].

    Args:
        series: Pandas Series containing binary values (0 or 1).
        lower: Minimum acceptable proportion.
        upper: Maximum acceptable proportion.

    Returns:
        bool: True if proportions are valid, False otherwise.
    """
    values = set(series.dropna().unique())
    
    # Invalid target variable
    if not values.issubset({0, 1}):
        return False
    
    # Check NA
    n = series.dropna().size
    if n == 0:
        return False

    p1 = series.mean()
    p0 = 1 - p1
    return (lower <= p0 <= upper) and (lower <= p1 <= upper)


# Pandera schema
schema = pa.DataFrameSchema(
    columns={
        TARGET: pa.Column(int, checks=pa.Check.isin([0, 1]), nullable=False),
    },
    checks=[
        # 1. Target distribution check
        pa.Check(
            lambda df: proportion_bounds(df[TARGET], *TARGET_PROP_BOUNDS),
            element_wise=False,
            error=f"Target '{TARGET}' class proportions must be within {TARGET_PROP_BOUNDS}.",
        )
    ],
)

# Run validation
try:
    validated = schema.validate(df, lazy=True)
    print("Validation passed. Data shape:", validated.shape)
except pa.errors.SchemaErrors as err:
    print("Validation failed. Failure cases:")
    pd.set_option("display.max_colwidth", None)
    print(err.failure_cases)
# Out:
# Validation passed. Data shape: (40687, 10)

# %%
from sklearn.model_selection import train_test_split

train_df, test_df = train_test_split(
    hotel_data_cleaned, test_size=0.3, random_state=123)

# %%
numeric_df = train_df.select_dtypes("number").describe().T[["mean", "std", "min", "max"]]
numeric_df
# Out:
#                                       mean         std  min    max
# is_canceled                       0.388659    0.487454  0.0    1.0
# lead_time                       108.929249  107.672365  0.0  629.0
# previous_cancellations            0.011692    0.181785  0.0    6.0
# previous_bookings_not_canceled    0.169312    1.733475  0.0   72.0
# booking_changes                   0.241362    0.677988  0.0   18.0
# total_of_special_requests         0.673490    0.845832  0.0    5.0
# is_repeated_guest                 0.035007    0.183801  0.0    1.0

# %%
categorical_df = train_df.select_dtypes("object").describe().T[["unique", "top", "freq"]]
categorical_df
# Out:
#                    unique         top   freq
# hotel                   2  City Hotel  19141
# deposit_type            3  No Deposit  25583
# reserved_room_type      9           D   5328

# %%
#Examining target variable distribution
target_df = pd.DataFrame(train_df["is_canceled"].value_counts(normalize=True).rename("prop"))
target_df
# Out:
#                  prop
# is_canceled
# 0            0.611341
# 1            0.388659

# %%
#Examining multicollinearity between predictor variables
corr = train_df.select_dtypes("number").corr()

plt.figure(figsize=(8, 6))
im = plt.imshow(corr, cmap="RdYlGn", vmin=-1, vmax=1)
cbar = plt.colorbar(im)
plt.title("Correlation Matrix")
plt.xticks(ticks=range(len(corr.columns)), labels=corr.columns, rotation=90)
plt.yticks(ticks=range(len(corr.columns)),labels=corr.columns)
plt.show()

# %% [markdown]
# figure 1

# %%
target_dist = alt.Chart(train_df[['is_canceled', 'hotel']]).mark_bar().encode(
    x='is_canceled:N',
    y='count()',
).properties(
    height=250, 
    width=300
)

target_dist_hotel_type = alt.Chart(train_df).mark_bar().encode(
    x='hotel:N',
    y='count()',
    color='is_canceled:N'
).properties(
    height=250, 
    width=300
)

target_dist | target_dist_hotel_type
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# figure 2

# %% [markdown]
# As we can see from the plot on the left, there is not a significant class imbalance. The number of cancellations is slightly lower than the number of non cancellations, however, the proportion of cancellations to non cancellations is not extremely different.
#
# The plot on the right shows that there are more cancellations for city hotels compared to resort hotels.

# %%
lead_time_plot = alt.Chart(train_df).transform_density(
    'lead_time',
    groupby= ['is_canceled'],
    as_=['lead_time', 'density'],
).mark_area().encode(
    x="lead_time:Q",
    y='density:Q',
    color='is_canceled:N'
)
lead_time_plot
# Out:
# alt.Chart(...)

# %% [markdown]
# figure 3

# %% [markdown]
# In the above density plot, we can see that cancelled bookings tend to have much higher lead times compared to bookings made more last minute (shorter lead times), which suggests that lead time could be a promising predictor for hotel cancellations.

# %%
repeated_guest = alt.Chart(train_df[['is_repeated_guest', 'deposit_type', 'reserved_room_type', 'is_canceled']]).mark_bar().encode(
    x='is_repeated_guest:N', 
    y='count()',
    color='is_canceled:N'
).properties(width=250)

deposit_type = alt.Chart(train_df).mark_bar().encode(
    x='deposit_type:N',
    y='count()',
    color='is_canceled:N'
).properties(width=250)


room_type = alt.Chart(train_df).mark_bar().encode(
    x='reserved_room_type:N',
    y='count()',
    color='is_canceled:N'
).properties(width=250)

repeated_guest | room_type | deposit_type
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# figure 4

# %% [markdown]
# We can observe from the plots above that almost all cancellations are happening for new guests. Repeated guests who have booked with the hotel before do not seem to cancel much. In addition, the majoirty of cancellations occur for guests who have booked room type A. Interestingly, guests seem to cancel more when they have not provided a deposit on their booking and some also cancel when their deposit is non refundable.

# %% [markdown]
# ## Data Validation: Part 2 — Checking Correlations

# %%
# Using train data only
df = train_df

# Target variable
TARGET = "is_canceled"

# Bounds for target class proportions (has to be binary 0 or 1)
TARGET_PROP_BOUNDS = (0.2, 0.8)

# Correlation thresholds
TARGET_FEATURE_CORR_THRESHOLD = 0.9
FEATURE_FEATURE_CORR_THRESHOLD = 0.9

# Features to exclude
EXCLUDE = set()

FEATURES = [col for col in df.columns if col != TARGET and col not in EXCLUDE]


# Helper functions
def has_no_anomalous_target_correlations(df, target, features, threshold):
    """
    Ensure Pearson correlations between target and numeric features
    do not exceed the given threshold.
    """
    numeric_cols = df[features].select_dtypes(include=[np.number]).columns.tolist()

    # No numeric cols
    if not numeric_cols:
        return True

    corr = df[[target] + numeric_cols].corr(numeric_only=True)[target].drop(target, errors="ignore")
    max_corr = corr.abs().max()

    return max_corr <= threshold


def has_no_anomalous_feature_correlations(df, features, threshold):
    """
    Ensure Pearson correlations among numeric features
    do not exceed the given threshold.
    """
    numeric_cols = df[features].select_dtypes(include=[np.number]).columns.tolist()
    
    # Less than 2 numeric columns
    if len(numeric_cols) < 2:
        return True

    tmp = df[numeric_cols].dropna()

    corr_matrix = tmp.corr(numeric_only=True).abs()
    np.fill_diagonal(corr_matrix.values, 0.0)
    max_corr = corr_matrix.max().max()

    return max_corr <= threshold


# Pandera schema
schema = pa.DataFrameSchema(
    columns={
        TARGET: pa.Column(int, checks=pa.Check.isin([0, 1]), nullable=False),
    },
    checks=[
        # 2. Target-feature correlation check
        pa.Check(
            lambda df: has_no_anomalous_target_correlations(
                df, TARGET, FEATURES, TARGET_FEATURE_CORR_THRESHOLD
            ),
            element_wise=False,
            error=f"Anomalous target-feature correlations detected (>|{TARGET_FEATURE_CORR_THRESHOLD}|).",
        ),
        # 3. Feature-feature correlation check
        pa.Check(
            lambda df: has_no_anomalous_feature_correlations(
                df, FEATURES, FEATURE_FEATURE_CORR_THRESHOLD
            ),
            element_wise=False,
            error=f"Anomalous feature-feature correlations detected (>|{FEATURE_FEATURE_CORR_THRESHOLD}|).",
        ),
    ],
)

# Run validation
try:
    validated = schema.validate(df, lazy=True)
    print("Validation passed. Data shape:", validated.shape)
except pa.errors.SchemaErrors as err:
    print("Validation failed. Failure cases:")
    pd.set_option("display.max_colwidth", None)
    print(err.failure_cases)
# Out:
# Validation passed. Data shape: (28480, 10)

# %% [markdown]
# ## Preprocessing + Feature Transformations

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

# %%
X_train = train_df.drop(columns=['is_canceled'])
y_train = train_df["is_canceled"]

X_test = test_df.drop(columns=['is_canceled'])
y_test = test_df["is_canceled"]

num_features = ["lead_time", "previous_cancellations", 'previous_bookings_not_canceled', 'booking_changes', 'total_of_special_requests']
cat_features = ["reserved_room_type", "deposit_type"]
binary_features = ['is_repeated_guest']

# %%
#defining transformers 
num_transformer = StandardScaler()
cat_transformer = OneHotEncoder(handle_unknown="ignore")

# %%
preprocessor = make_column_transformer(    
    (num_transformer, num_features),
    ("passthrough", binary_features),   
    (cat_transformer, cat_features)
)

# %% [markdown]
# ## Results:

# %%
# Defining three models we are using to test 
knn = KNeighborsClassifier(n_neighbors=15)
dt = DecisionTreeClassifier(max_depth=6, random_state=123)
svm_rbf = SVC(kernel="rbf", C=1.0, gamma="scale", probability=True, random_state=123)

# Building the pipelines
pipe_knn = make_pipeline(preprocessor, knn)
pipe_dt = make_pipeline(preprocessor, dt)
pipe_svm = make_pipeline(preprocessor, svm_rbf)

# %%
from sklearn.model_selection import cross_val_score

pipelines = {
    "KNN": pipe_knn,
    "DecisionTree": pipe_dt,
    "SVM_RBF": pipe_svm
}

cv_results = {}

#We are using 5-fold CV and comparing F1 scores 
for name, pipe in pipelines.items():
    scores = cross_val_score(pipe, X_train, y_train, cv=5, scoring="f1")
    cv_results[name] = scores
    print(f"{name}: mean F1 = {scores.mean():.3f} ± {scores.std():.3f}")
# Out:
# KNN: mean F1 = 0.601 ± 0.010
# DecisionTree: mean F1 = 0.572 ± 0.010

# %%
best_pipe = pipe_knn
best_pipe.fit(X_train, y_train)

y_pred = best_pipe.predict(X_test)
y_proba = best_pipe.predict_proba(X_test)[:, 1]

# %%
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    classification_report
)

# Overall accuracy
test_accuracy = accuracy_score(y_test, y_pred)
print(f"Test accuracy: {test_accuracy:.3f}")

# Confusion matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion matrix:\n", cm)

# %%
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt

cm_disp = ConfusionMatrixDisplay.from_estimator(
    best_pipe,          
    X_test,
    y_test,
    display_labels=["not_canceled", "canceled"],
    values_format="d"   
)

plt.title("Confusion Matrix - KNN (Test Set)")
plt.show()

# %% [markdown]
# figure 5

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# Computing FPR, TPR, Thresholds
fpr, tpr, thresholds = roc_curve(y_test, y_proba)

# Computing AUC
auc = roc_auc_score(y_test, y_proba)

# ROC Plot
plt.figure(figsize=(6, 5))
plt.plot(fpr, tpr, label=f"AUC = {auc:.3f}")
plt.plot([0, 1], [0, 1], linestyle="--", color="gray")  # chance line
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - KNN Model")
plt.legend(loc="lower right")
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# figure 6

# %% [markdown]
# ## Discussion of Results

# %% [markdown]
# With this project, our primary goal was to predict the whether a hotel bookings would eventually end up being cancelled, using information that is available at the time of booking including lead time, deposit type, room type and whether the guest is a repeat customer etc. The idea is that a reasonably accurate model could help hotel businesses flag high-risk bookings and adjust their policies or communication before the stay date.
#
# For the purpose of getting the best model to do this prediction, we compared three classification models using 5-fold cross validation on the training set, with F1 score (for the cancellation class) as the main metric, **K-Nearest Neighbours (KNN, k = 15), Decision Tree (max_depth = 6), and RBF-kernel SVM (C = 1.0, gamma = “scale”).** After scoring their mean F1 scores on the training folds, the F1 score results were: F1 = 0.602 for KNN, F1= 0.57 for Decision Tree and F1=0.526 for RBF SVM.
# KNN clearly performed best on this metric, and also consistently across the folds with the least standard deviations. Because our main concern is to correctly identify cancellations rather than just overall accuracy, we chose **KNN** as the final model for evaluation on the test set.
#
# **Performace on the test set and confusion matrix stats:**
#
# On the test dat, the KNN model achieved an accuracy of 0.733. Other stats are as follows:
#
# - Cancellation Precision ≈ 0.70
# - Cancellation Recall ≈ 0.53
# - Cancellation F1 ≈ 0.60
# - Non-Cancellation Precision ≈ 0.75
# - Non-Cancellation Recall ≈ 0.86
# - Non-Cancellation F1 ≈ 0.80
#
# The averaged F1 is close to 0.70, which is close to what we saw in the cross validation for the cancellation class. This suggests that the model do generally well enough and does not drastically overfit the training data.
#
# If we assume a rough baseline of always predicting “not cancelled”, the model would give an accuracy of 62%. So looking into that, our KNN model improves this by about 73% which also provides a meaningful recall for the cancellation class. Our model leans slightly towards being a bit cautious about over-flagging cancellations (higher position than recall for positive class). But in practice, this is acceptable, as the hotel would want to avoid annoying, loyal and serious guests with extra checks, but it also would be very useful in catching more of these genuinely risky bookings.
#
# **Limitations to keep in mind when interpreting :**
#
# - **Feature and dataset limitations:** The dataset has restricted us with booking data from only one year - 2017, and also it is taken from a mix for too many countries. This simplifies the problem but may limit how well the model generalizes to other years with different travel patterns or external events. The analysis might differ from location to location and country to country. We used a small, curated set of features thus including more information (such as market segment, distribution channel, length of stay or country) could help the model learn more subtle patterns and improve recall for cancellations.
# - **No hyperparameter tuning yet:** We used fixed hyperparameters (e.g., k = 15 for KNN) rather than performing a grid search or randomized search. Systematic tuning could yield a better balance between precision and recall for the cancellation class.
# - **Single threshold:** We used the default decision threshold of 0.5. For a real hotel, it might be better to adjust this threshold depending on whether they are more concerned about missed cancellations or about over-flagging guests.
#
# **Overall takeaway:**
#
# In overall, the KNN model provides a **useful starting point** for predicting hotel booking cancellations. It clearly outperforms a simple majority baseline, correctly identifies most non-cancellations and captures a meaningful portion of actual cancellations. With additional tuning, more features and a more careful treatment of missing values and thresholds, this approach could be developed into a practical decision support tool to help hotels manage overbooking strategies, communicate proactively with high-risk guests and reduce the last minute revenue losses.

# %% [markdown]
# ## References

# %% [markdown]
# Antonio, N., de Almeida, A., & Nunes, L. (2017, December). Predicting hotel bookings cancellation with a machine learning classification model. In 2017 16th IEEE International Conference on Machine Learning and Applications (ICMLA) (pp. 1049-1054). IEEE.
#
# Antonio, N., De Almeida, A., & Nunes, L. (2019). Big data in hotel revenue management: Exploring cancellation drivers to gain insights into booking cancellation behavior. Cornell Hospitality Quarterly, 60(4), 298-319.
#
# Antonio, N., de Almeida, A., & Nunes, L. (2019). Hotel booking demand datasets. Data in brief, 22, 41-49.
#
# Chen, S., Ngai, E. W. T., Ku, Y., Xu, Z., Gou, X., & Zhang, C. (2023). Prediction of hotel booking cancellations: Integration of machine learning and probability model based on interpretable feature interaction. Decision Support Systems, 170.
#
# Sánchez, E. C., Sánchez-Medina, A. J., & Pellejero, M. (2020). Identifying critical hotel cancellations using artificial intelligence. Tourism Management Perspectives, 35.
#
# Yang, D., & Miao, X. (2024). Predicting hotel booking cancellations using tree-based neural network. PeerJ Computer Science, 10.
